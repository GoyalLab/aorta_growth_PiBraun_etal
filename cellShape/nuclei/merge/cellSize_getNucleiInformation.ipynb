# %%
import numpy as np
import pandas as pd
from skimage.measure import regionprops_table
import os
from os import listdir
from os.path import isfile, join

# %%
nucleiPath = "/Volumes/My Passport/aorta/segmentations_tilesNuc"

# %%
folders = [x[0] for x in os.walk(nucleiPath)]
folders = sorted(folders)

# %%
df = pd.DataFrame()
for folder in folders:
    os.chdir(folder)
    files = [f for f in listdir(folder) if isfile(join(folder, f)) if ".DS_Store" not in f if ".npy" in f if "._" not in f]
    for file in files:
        aorta = folder.split("/")[-1]
        age = folder.split("/")[-2]
        nucleiMasks =  np.load(join(folder, file), allow_pickle=True).item()['masks']
        prop_dict = regionprops_table(nucleiMasks, properties = ('label', 'area', 'major_axis_length', 'minor_axis_length'))
        dfHelp = pd.DataFrame(prop_dict)
        dfHelp['age'] = age
        dfHelp['aorta'] = aorta
        dfHelp['file'] = file
        df = pd.concat([df,dfHelp])

# %%
df = df.reset_index(drop=True)

# %%
df['aspectRatio'] = df['major_axis_length']/df['minor_axis_length']

# %%
df = pd.read_csv('/Volumes/My Passport/aorta/results/cellShape/statsNuclei.csv')

# %%
dfCount = df.groupby(['age', 'aorta']).count()

# %%
dfCount.to_csv('/Volumes/My Passport/aorta/results/cellShape/statsNuclei_Count.csv')

# %%
dfMean = df.groupby(['age', 'aorta']).mean()

# %%
dfMedian = df.groupby(['age', 'aorta']).median()

# %%
dfMean
# Out:
#                    label        area  major_axis_length  minor_axis_length  \
# age aorta
# P03 aorta01  1076.966977  110.217295          20.132514           6.987140
#     aorta02   794.612675  105.739571          19.288378           7.062209
#     aorta03   950.937001  152.394412          24.560342           7.986562
#     aorta04   710.233414  140.067280          22.930347           7.905783
# P05 aorta01   967.299820   73.144257          18.255422           5.269072
#     aorta02   325.876415   71.652245          15.229367           6.057340
#     aorta03   670.645306   70.484979          17.985167           5.140276
#     aorta04   499.052895   62.101369          16.369481           4.950779
#     aorta05   239.802852   58.720512          16.449433           4.616856
#     aorta06  1123.506549   70.363294          17.784654           5.209774
#     aorta07  1014.923388   68.370823          17.487868           5.141935
#     aorta08   832.460919   72.254372          18.640539           5.076602
# P07 aorta01   880.542905  174.724853          24.728103           9.065776
#     aorta02   633.091122  187.008622          25.193823           9.410556
#     aorta03   654.584042   81.883598          19.244182           5.566252
#     aorta04  1074.742427  122.926453          20.659093           7.646445
# P10 aorta01   661.218851   76.831182          18.753121           5.360779
#     aorta02   900.831016   81.250567          19.014584           5.609801
#     aorta03   836.902129   83.385976          19.327434           5.647662
#     aorta04   823.770478   80.242010          19.101037           5.498720
# P14 aorta01   715.822714   93.535431          20.635512           5.912430
#     aorta02   673.696881   87.880244          20.162486           5.714149
#     aorta03   610.931041   89.278340          21.002593           5.560841
#     aorta04   617.315725   87.895057          20.806841           5.543179
# P21 aorta01   719.406277   74.791824          15.956559           6.054897
#     aorta02   858.541222  104.951241          22.094878           6.205000
#     aorta03   736.820942  108.678005          23.254965           6.081779
#     aorta04   740.173885  103.571711          21.625668           6.245303
#     aorta05   720.719732  102.291372          20.778292           6.405073
#     aorta06   735.019678  104.655517          21.782660           6.270979
#     aorta07   736.642353  105.508929          21.595703           6.385042
# P30 aorta01   652.884009  100.713065          21.300419           6.170265
#     aorta02   712.152991   95.770448          20.213303           6.195363
#     aorta03   678.681706   94.867318          19.909410           6.257462
#     aorta04   668.440805  105.460474          22.314378           6.190568
# P60 aorta01   637.260078   83.961508          18.401177           5.944266
#     aorta02   754.738860   90.673055          19.377887           6.129875
#     aorta03   699.512965   96.687137          19.545790           6.451657
#     aorta04   642.677878   96.368994          19.946331           6.296987
#
#              aspectRatio
# age aorta
# P03 aorta01     2.976878
#     aorta02     2.860210
#     aorta03     3.167470
#     aorta04     2.988439
# P05 aorta01     3.673513
#     aorta02     2.662152
#     aorta03     3.729430
#     aorta04     3.517401
#     aorta05     3.749390
#     aorta06     3.642935
#     aorta07     3.618691
#     aorta08     3.880040
# P07 aorta01     2.784155
#     aorta02     2.731405
#     aorta03     3.608428
#     aorta04     2.776587
# P10 aorta01     3.664899
#     aorta02     3.532089
#     aorta03     3.550000
#     aorta04     3.611037
# P14 aorta01     3.615681
#     aorta02     3.665527
#     aorta03     3.895980
#     aorta04     3.869355
# P21 aorta01     2.738518
#     aorta02     3.689323
#     aorta03     3.938825
#     aorta04     3.559289
#     aorta05     3.345188
#     aorta06     3.585189
#     aorta07     3.485426
# P30 aorta01     3.583145
#     aorta02     3.381177
#     aorta03     3.302228
#     aorta04     3.742006
# P60 aorta01     3.223683
#     aorta02     3.319889
#     aorta03     3.143726
#     aorta04     3.268923

# %%
dfMedian
# Out:
#               label   area  major_axis_length  minor_axis_length  aspectRatio
# age aorta
# P03 aorta01   983.0  111.0          20.960260           6.781958     2.946860
#     aorta02   747.0  107.0          20.043433           6.809687     2.822877
#     aorta03   890.0  139.0          23.932656           7.715053     3.089088
#     aorta04   677.0  133.0          22.526143           7.697257     2.918045
# P05 aorta01   809.0   71.0          18.313672           5.128779     3.561637
#     aorta02   248.0   66.0          14.952581           5.777591     2.571869
#     aorta03   564.0   68.0          17.930438           4.927599     3.632192
#     aorta04   450.0   58.0          16.288398           4.693022     3.427615
#     aorta05   209.0   55.0          16.321756           4.387581     3.653503
#     aorta06  1049.0   67.0          17.772286           4.976284     3.530978
#     aorta07   855.0   66.0          17.503090           4.975987     3.498250
#     aorta08   716.0   69.0          18.580079           4.892042     3.776884
# P07 aorta01   845.0  169.0          24.381009           8.984542     2.721085
#     aorta02   549.0  178.0          24.844039           9.267114     2.670752
#     aorta03   565.0   81.0          19.476993           5.427173     3.553846
#     aorta04   953.0  129.0          21.968332           7.535946     2.798780
# P10 aorta01   534.0   76.0          18.969952           5.206108     3.601244
#     aorta02   804.0   80.0          19.223621           5.488497     3.473625
#     aorta03   718.0   83.0          19.615777           5.558023     3.497731
#     aorta04   731.5   80.0          19.360198           5.379980     3.566308
# P14 aorta01   662.0   95.0          21.355577           5.868735     3.594170
#     aorta02   586.0   90.0          20.972329           5.614629     3.668434
#     aorta03   540.0   91.0          21.743957           5.496467     3.910880
#     aorta04   522.0   89.0          21.385957           5.456054     3.877937
# P21 aorta01   665.0   74.0          16.137224           5.997558     2.672715
#     aorta02   834.0  108.0          22.936800           6.167988     3.684122
#     aorta03   706.0  113.0          24.153349           6.111958     3.917649
#     aorta04   686.0  106.0          22.240681           6.238591     3.532450
#     aorta05   637.0  105.0          21.317188           6.403768     3.298650
#     aorta06   669.0  105.0          22.134069           6.264215     3.524650
#     aorta07   688.0  107.0          21.947543           6.359250     3.428625
# P30 aorta01   587.0  103.0          21.871665           6.149026     3.537000
#     aorta02   648.0   97.0          20.690240           6.159500     3.347424
#     aorta03   615.0   96.0          20.211699           6.165530     3.255624
#     aorta04   610.0  106.0          22.739550           6.130779     3.703264
# P60 aorta01   575.0   86.0          18.867320           5.885518     3.149911
#     aorta02   697.0   91.0          19.630977           6.072725     3.213575
#     aorta03   629.0   98.0          19.907481           6.410714     3.063907
#     aorta04   586.0   99.0          20.656286           6.237242     3.249000

# %%
df.to_csv("/Volumes/My Passport/aorta/results/cellShape/statsNuclei.csv", index=False)
